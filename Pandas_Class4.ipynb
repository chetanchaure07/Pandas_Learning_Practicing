# %%
import pandas as pd

# %% [markdown]
# # 🐼 Pandas - Class 4: Data Selection & Filtering
# Welcome to **Class 4** of our Pandas series. Today we’ll explore techniques to select and filter data in a DataFrame.

# %% [markdown]
# ## 1. Boolean Indexing & Conditional Selection
# - Use comparison operators to build conditions (e.g., `df['col'] > 50`).
# - Pass the condition inside `df[...]` to get matching rows.
# - Combine multiple conditions with `&` (AND), `|` (OR), and `~` (NOT).
# - Parentheses are required when combining conditions.

# %%
a = pd.DataFrame({
    "Name" : ['Tanishq', 'Atishay', 'Krishna', 'Raj', 'Chetan'],
    "Age" : [21, 42, 32, 37, 25],
    "Score" : [70, 65, 70, 80, 85]
})
print(a, '\n')

#1. Single condition: rows where Age > 30
print(a[a['Age'] > 30], '\n')

#2. Condition 2: Score >= 80
print(a[a['Score'] >= 80], '\n')

#3. Multiple conditions: Age >= 25 AND Score > 80
print(a[(a['Age'] >= 25) & (a['Score'] > 80)], '\n')

print(a[(a['Age'] >= 25) | (a['Score'] > 80)], '\n')

print(a[~(a['Score'] > 80)], '\n')
# (codition1) operator(and = & , or = | , not = ~ ) (condition2)
# Out:
#       Name  Age  Score
# 0  Tanishq   21     70
# 1  Atishay   42     65
# 2  Krishna   32     70
# 3      Raj   37     80
# 4   Chetan   25     85
#
#       Name  Age  Score
# 1  Atishay   42     65
# 2  Krishna   32     70
# 3      Raj   37     80
#
#      Name  Age  Score
# 3     Raj   37     80
# 4  Chetan   25     85
#
#      Name  Age  Score
# 4  Chetan   25     85
#
#       Name  Age  Score
# 1  Atishay   42     65
# 2  Krishna   32     70
# 3      Raj   37     80
# 4   Chetan   25     85
#
#       Name  Age  Score
# 0  Tanishq   21     70
# 1  Atishay   42     65
# 2  Krishna   32     70
# 3      Raj   37     80

# %% [markdown]
# ## 2. Filtering Rows with Multiple Conditions
# - Combine two or more conditions to refine selection.
# - Remember to enclose each condition in parentheses.

# %%
#1. Age >= 25 AND Score >= 85
#2. Age < 35 OR Score >= 80
#3. Age between 25 and 35 (inclusive.)

# 1.
print(a[(a['Age'] >= 25) & (a['Score'] >= 85)], '\n')

# 2.
print(a[(a['Age'] < 35) | (a['Score'] >= 80)], '\n')

# 3.
print(a[(a['Age'] >= 25) & (a['Age'] <=35)])
# Out:
#      Name  Age  Score
# 4  Chetan   25     85
#
#       Name  Age  Score
# 0  Tanishq   21     70
# 2  Krishna   32     70
# 3      Raj   37     80
# 4   Chetan   25     85
#
#       Name  Age  Score
# 2  Krishna   32     70
# 4   Chetan   25     85

# %% [markdown]
# ## 3. Using `query()` for Cleaner Filtering
# - `query()` allows filtering rows with a string expression.
# - It's concise and readable for complex conditions.
# - Variables can be passed using the `@` symbol.

# %%
#simple query: Age > 25
print(a.query("Age > 25"), '\n')

#Age < 35 and Score >= 85
print(a.query("Age < 35" and "Score >= 85"), '\n')

s = 75
print(a.query('Score > @s    \n')) # @ ke baad variable aayega
# Out:
#       Name  Age  Score
# 1  Atishay   42     65
# 2  Krishna   32     70
# 3      Raj   37     80
#
#      Name  Age  Score
# 4  Chetan   25     85
#
#      Name  Age  Score
# 3     Raj   37     80
# 4  Chetan   25     85

# %% [markdown]
# ## 4. String Operations on Columns
# - Use the `.str` accessor for vectorized string methods.
# - Common methods: `contains`, `replace`, `startswith`, `endswith`, `lower`, `upper`.
# - Useful for cleaning or filtering text data.

# %%
# 1. Convert to LowerCase.
print(a['Name'].str.lower(), '\n')

# 2. Convert to UpperCase.
print(a['Name'].str.upper(), '\n')

# 3. Check if name contains the letter 'a'
print(a[a['Name'].str.contains('a')], '\n')

# 4. Replace a substring to something else
print(a['Name'].str.replace('Tanishq', 'Mohit'), '\n')

# 5. Filter rows where name starts with 'd'
print(a['Name'].str.startswith('D'), '\n')

# 6. Filter rows where name ends with 'e'
print(a[a['Name'].str.endswith('e')])
# Out:
# 0    tanishq
# 1    atishay
# 2    krishna
# 3        raj
# 4     chetan
# Name: Name, dtype: object
#
# 0    TANISHQ
# 1    ATISHAY
# 2    KRISHNA
# 3        RAJ
# 4     CHETAN
# Name: Name, dtype: object
#
#       Name  Age  Score
# 0  Tanishq   21     70
# 1  Atishay   42     65
# 2  Krishna   32     70
# 3      Raj   37     80
# 4   Chetan   25     85
#
# 0      Mohit
# 1    Atishay
# 2    Krishna
# 3        Raj
# 4     Chetan
# Name: Name, dtype: object
#
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: Name, dtype: bool
#
# Empty DataFrame
# Columns: [Name, Age, Score]
# Index: []

# %% [markdown]
# ## Mini Practice
# 1. Build a DataFrame with columns such as Name, Age, City, Score.
# 2. Use boolean indexing to select rows where Age > 25.
# 3. Filter rows where City is either 'Delhi' or 'Mumbai'.
# 4. Use query() to find rows with Score >= 85 and Age < 35.
# 5. Clean a text column using str.replace or str.lower.

# %%
import pandas as pd
# 1. Build a DataFrame with columns: Name, Age, City, Score
# Write your code here
data = {
    'Name' : ['Chetan', 'Mohit', 'Yash', 'Suman', 'Piyush'],
    'Age' : [19, 20, 24, 18, 25],
    'City' : ['Bhopa', 'Pandhurna', 'Nagpur', 'Ayodhya', 'Pandhurna'],
    'Score' : [90, 95, 56, 80, 35]
}
df = pd.DataFrame(data)
print(df, '\n')


# 2. Use boolean indexing to select rows where Age > 25
# Write your code here
print(df['Age'] > 25, '\n')

# 3. Filter rows where City is either 'Delhi' or 'Mumbai'
# Write your code here
# print(df[(df['City'] == 'Delhi') | (df['City'] == 'Mumbai')])
print(df[df['City'].isin(['Delhi', 'Mumbai'])], '\n')

# 4. Use query() to find rows with Score >= 85 and Age < 35
# Write your code here
print(df.query("Score >= 85 and Age < 35"), '\n')

# 5. Clean a text column using str.replace or str.lower
# Example: convert City names to lowercase or replace "delhi" with "New Delhi"
# Write your code here
print(df['City'].str.lower(), '\n')
print(df['City'].str.replace('Bhopa', 'bhopal'))
# Out:
#      Name  Age       City  Score
# 0  Chetan   19      Bhopa     90
# 1   Mohit   20  Pandhurna     95
# 2    Yash   24     Nagpur     56
# 3   Suman   18    Ayodhya     80
# 4  Piyush   25  Pandhurna     35
#
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: Age, dtype: bool
#
# Empty DataFrame
# Columns: [Name, Age, City, Score]
# Index: []
#
#      Name  Age       City  Score
# 0  Chetan   19      Bhopa     90
# 1   Mohit   20  Pandhurna     95
#
# 0        bhopa
# 1    pandhurna
# 2       nagpur
# 3      ayodhya
# 4    pandhurna
# Name: City, dtype: object
#
# 0       bhopal
# 1    Pandhurna
# 2       Nagpur
# 3      Ayodhya
# 4    Pandhurna
# Name: City, dtype: object

# %% [markdown]
# ---
# ## Summary
# - Learned to use boolean indexing and conditional selection.
# - Filtered rows with multiple conditions.
# - Used `query()` for clean filtering.
# - Applied string operations with the `.str` accessor.
