# %% [markdown]
# # Pandas Assignment (Q1–Q15)
#
# Fill the code in the empty code cells.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Q1. Create the **Below** DataFrame.
#
# Expected Output:
# ```
#     Name   Age  Marks     City
# 0   Aman  20.0   85.0    Delhi
# 1   Neha   NaN   92.0   Mumbai
# 2   Ravi  19.0    NaN     Pune
# 3  Priya  22.0   88.0  Indore
# 4  Karan  20.0   95.0      NaN
# ```

# %%
data = {
    'Name' : ['Aman', 'Neha', 'Ravi', 'Priya', 'Karan'],
    'Age' : [20, np.nan, 19, 22, 20],
    'Marks' : [85, 92, np.nan, 88, 95],
    'City' : ['Delhi', 'Mumbai', 'Pune', 'Indore', np.nan]
}
df = pd.DataFrame(data)
df
# Out:
#     Name   Age  Marks    City
# 0   Aman  20.0   85.0   Delhi
# 1   Neha   NaN   92.0  Mumbai
# 2   Ravi  19.0    NaN    Pune
# 3  Priya  22.0   88.0  Indore
# 4  Karan  20.0   95.0     NaN

# %% [markdown]
# ## Q2. Display the first 3 rows.

# %%
df.head(2)
# Out:
#    Name   Age  Marks    City
# 0  Aman  20.0   85.0   Delhi
# 1  Neha   NaN   92.0  Mumbai

# %% [markdown]
# ## Q3. Display the last 2 rows.

# %%
df.tail(2)
# Out:
#     Name   Age  Marks    City
# 3  Priya  22.0   88.0  Indore
# 4  Karan  20.0   95.0     NaN

# %% [markdown]
# ## Q4. Find the shape of the DataFrame.

# %%
df.shape
# Out:
# (5, 4)

# %% [markdown]
# ## Q5. Display all column names.

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'Marks', 'City'], dtype='object')

# %% [markdown]
# ## Q6. Display the data types of all columns.

# %%
df.dtypes
# Out:
# Name      object
# Age      float64
# Marks    float64
# City      object
# dtype: object

# %% [markdown]
# ## Q7. Find the total number of missing values in each column using `isnull().sum()`.
#
# Expected Output:
# ```
# Name     0
# Age      1
# Marks    1
# City     1
# dtype: int64
# ```

# %%
df.isnull().sum()
# Out:
# Name     0
# Age      1
# Marks    1
# City     1
# dtype: int64

# %% [markdown]
# ## Q8. Fill missing values in the Age column with **21** using `fillna()`.

# %%
df['Age'] = df['Age'].fillna(21)
df['Age']
# Out:
# 0    20.0
# 1    21.0
# 2    19.0
# 3    22.0
# 4    20.0
# Name: Age, dtype: float64

# %% [markdown]
# ## Q9. Fill missing values in the Marks column with the column mean.

# %%
df['Marks'] = df['Marks'].fillna(df['Marks'].mean())
print(df['Marks'].mean())
df
# Out:
# 90.0
#     Name   Age  Marks    City
# 0   Aman  20.0   85.0   Delhi
# 1   Neha  21.0   92.0  Mumbai
# 2   Ravi  19.0   90.0    Pune
# 3  Priya  22.0   88.0  Indore
# 4  Karan  20.0   95.0     NaN

# %% [markdown]
# ## Q10. Fill missing values in the City column with **Unknown**.

# %%
df['City'] = df['City'].fillna('Unknown')
df
# Out:
#     Name   Age  Marks     City
# 0   Aman  20.0   85.0    Delhi
# 1   Neha  21.0   92.0   Mumbai
# 2   Ravi  19.0   90.0     Pune
# 3  Priya  22.0   88.0   Indore
# 4  Karan  20.0   95.0  Unknown

# %% [markdown]
# ## Q11. Select only the Name and Marks columns.

# %%
df[['Name', 'Marks']]
# Out:
#     Name  Marks
# 0   Aman   85.0
# 1   Neha   92.0
# 2   Ravi   90.0
# 3  Priya   88.0
# 4  Karan   95.0

# %% [markdown]
# ## Q12. Using `loc`, print the first 3 rows.

# %%
df.loc[0:2]
# Out:
#    Name   Age  Marks    City
# 0  Aman  20.0   85.0   Delhi
# 1  Neha  21.0   92.0  Mumbai
# 2  Ravi  19.0   90.0    Pune

# %% [markdown]
# ## Q13. Using `iloc`, print rows 1 to 3 and columns 0 to 2.

# %%
df.iloc[ 1:4 , 0:3 ]
# Out:
#     Name   Age  Marks
# 1   Neha  21.0   92.0
# 2   Ravi  19.0   90.0
# 3  Priya  22.0   88.0

# %% [markdown]
# ## Q14. Rename the column Marks to Score.

# %%
df = df.rename(columns={ 'Marks' : 'Score' })
df
# Out:
#     Name   Age  Score     City
# 0   Aman  20.0   85.0    Delhi
# 1   Neha  21.0   92.0   Mumbai
# 2   Ravi  19.0   90.0     Pune
# 3  Priya  22.0   88.0   Indore
# 4  Karan  20.0   95.0  Unknown

# %% [markdown]
# ## Q15. Set Name as the index.

# %%
df = df.set_index('Name')
df
# Out:
#         Age  Score     City
# Name
# Aman   20.0   85.0    Delhi
# Neha   21.0   92.0   Mumbai
# Ravi   19.0   90.0     Pune
# Priya  22.0   88.0   Indore
# Karan  20.0   95.0  Unknown

# %% [markdown]
# ## Q16. Reset Name as the index.

# %%
df = df.reset_inde
