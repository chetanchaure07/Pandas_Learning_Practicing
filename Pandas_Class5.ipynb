# %%
import pandas as pd

# %% [markdown]
# # 🐼 Pandas - Class 5: Sorting & Basic Statistics
# Welcome to **Class 5** of our Pandas series. Today we’ll learn how to sort data and calculate basic statistics.

# %%
data = {
  "Name": ["Alice", "Bob", "Charlie", "Diana", "Ethan", "Fiona"],
  "Age": [25, 30, 28, 32, 27, 29],
  "City": ["Bhopal", "Indore", "Delhi", "Mumbai", "Pune", "Jaipur"],
  "Salary": [45000, 52000, 48000, 60000, 50000, 47000]
}
df = pd.DataFrame(data)

# %% [markdown]
# ## 1. Sorting Data
# - Use `sort_values(by='col')` to sort by column values.
# - Use `ascending=False` for descending order.
# - Sort by multiple columns by passing a list.
# - `sort_index()` sorts by row or column index.

# %%
print(df.sort_values(by='Salary'), '\n')
print(df.sort_values(by='Age', ascending=True), '\n')
print(df.sort_values(by=['Age', 'Salary']), '\n')
print(df.sort_index(ascending=False))
# Out:
#       Name  Age    City  Salary
# 0    Alice   25  Bhopal   45000
# 5    Fiona   29  Jaipur   47000
# 2  Charlie   28   Delhi   48000
# 4    Ethan   27    Pune   50000
# 1      Bob   30  Indore   52000
# 3    Diana   32  Mumbai   60000
#
#       Name  Age    City  Salary
# 0    Alice   25  Bhopal   45000
# 4    Ethan   27    Pune   50000
# 2  Charlie   28   Delhi   48000
# 5    Fiona   29  Jaipur   47000
# 1      Bob   30  Indore   52000
# 3    Diana   32  Mumbai   60000
#
#       Name  Age    City  Salary
# 0    Alice   25  Bhopal   45000
# 4    Ethan   27    Pune   50000
# 2  Charlie   28   Delhi   48000
# 5    Fiona   29  Jaipur   47000
# 1      Bob   30  Indore   52000
# 3    Diana   32  Mumbai   60000
#
#       Name  Age    City  Salary
# 5    Fiona   29  Jaipur   47000
# 4    Ethan   27    Pune   50000
# 3    Diana   32  Mumbai   60000
# 2  Charlie   28   Delhi   48000
# 1      Bob   30  Indore   52000
# 0    Alice   25  Bhopal   45000

# %% [markdown]
# ## 2. Descriptive Statistics
# - `mean()`, `median()`, `mode()` for central tendency.
# - `std()` for standard deviation.
# - `describe()` for a summary of stats (count, mean, std, min, quartiles, max).

# %%
df = pd.DataFrame({
    "Name": ["A", "B", "C", "D", "E"],
    "Marks": [70, 80, 80, 90, 99]
})
print(df, '\n')

print(df["Marks"].mean())
print(df["Marks"].median())
print(df["Marks"].mode(), '\n')

print(df['Marks'].std(), '\n')

print(df['Marks'].describe())
# Out:
#   Name  Marks
# 0    A     70
# 1    B     80
# 2    C     80
# 3    D     90
# 4    E     99
#
# 83.8
# 80.0
# 0    80
# Name: Marks, dtype: int64
#
# 11.054410884348382
#
# count     5.000000
# mean     83.800000
# std      11.054411
# min      70.000000
# 25%      80.000000
# 50%      80.000000
# 75%      90.000000
# max      99.000000
# Name: Marks, dtype: float64

# %% [markdown]
# ## 3. Counting Values
# - `value_counts()` shows the frequency of unique values in a Series.
# - Use `normalize=True` to see percentages instead of counts.

# %%
df = pd.DataFrame({
    "Name": ["A", "B", "C", "D", "E", "F"],
    "Gender": ["Male", "Female", "Male", "Male", "Male", "Female"]
})
print(df, '\n')

print(df['Gender'].value_counts())

print(df['Gender'].value_counts(normalize=True))
# Out:
#   Name  Gender
# 0    A    Male
# 1    B  Female
# 2    C    Male
# 3    D    Male
# 4    E    Male
# 5    F  Female
#
# Gender
# Male      4
# Female    2
# Name: count, dtype: int64
# Gender
# Male      0.666667
# Female    0.333333
# Name: proportion, dtype: float64

# %% [markdown]
# ## 4. Correlation & Covariance
# - `corr()` computes correlation between numeric columns.
# - `cov()` computes covariance.
# - Correlation values range from -1 (negative) to +1 (positive).

# %%
df = pd.DataFrame({
    "Hours_Studied": [1, 2, 3, 4, 5],
    "Marks": [40, 50, 60, 70, 80]
})
print(df, '\n')

print(df['Hours_Studied'].corr(df['Marks']))

print(df['Hours_Studied'].cov(df['Marks']))
# Out:
#    Hours_Studied  Marks
# 0              1     40
# 1              2     50
# 2              3     60
# 3              4     70
# 4              5     80
#
# 1.0
# 25.0

# %% [markdown]
# ## Mini Practice
# 1. Build a DataFrame with columns: Name, Age, Score, Height.
# 2. Sort the data by Score (descending).
# 3. Get mean, median, mode, and std of numeric columns.
# 4. Use value_counts on Name or any categorical column.
# 5. Compute corr() and cov() for all numeric columns.

# %%
# Write your mini practice solution here
import pandas as pd

# 1. Build a DataFrame with columns: Name, Age, Score, Height
df = pd.DataFrame({
    "Name": ["Rahul", "Priya", "Aman", "Neha", "Rohan"],
    "Age": [20, 22, 21, 23, 20],
    "Score": [85, 90, 75, 95, 80],
    "Height": [170, 165, 175, 160, 172]
})

print(df, '\n')


# 2. Sort the data by Score (descending)
# Write your code here
print(df.sort_values(by='Score', ascending=False), '\n')


# 3. Get mean, median, mode, and std of numeric columns
# Write your code here
print(df.describe(), '\n')
print("Mean : \n",df[['Age', 'Score', 'Height']].mean())
print("Median : \n",df[['Age', 'Score', 'Height']].median())
print("Mode : \n",df[['Age', 'Score', 'Height']].mode())
print("STD : \n",df[['Age', 'Score', 'Height']].std())

# 4. Use value_counts on Name or any categorical column
# Write your code here
print(df['Name'].value_counts())

# 5. Compute corr() and cov() for all numeric columns
# Write your code here
print(df['Age'].corr(df['Score']))
print(df['Age'].cov(df['Score']))
# Out:
#     Name  Age  Score  Height
# 0  Rahul   20     85     170
# 1  Priya   22     90     165
# 2   Aman   21     75     175
# 3   Neha   23     95     160
# 4  Rohan   20     80     172
#
#     Name  Age  Score  Height
# 3   Neha   23     95     160
# 1  Priya   22     90     165
# 0  Rahul   20     85     170
# 4  Rohan   20     80     172
# 2   Aman   21     75     175
#
#             Age      Score     Height
# count   5.00000   5.000000    5.00000
# mean   21.20000  85.000000  168.40000
# std     1.30384   7.905694    5.94138
# min    20.00000  75.000000  160.00000
# 25%    20.00000  80.000000  165.00000
# 50%    21.00000  85.000000  170.00000
# 75%    22.00000  90.000000  172.00000
# max    23.00000  95.000000  175.00000
#
# Mean :
#  Age        21.2
# Score      85.0
# Height    168.4
# dtype: float64
# Median :
#  Age        21.0
# Score      85.0
# Height    170.0
# dtype: float64
# Mode :
#      Age  Score  Height
# 0  20.0     75     160
# 1   NaN     80     165
# 2   NaN     85     170
# 3   NaN     90     172
# 4   NaN     95     175
# STD :
#  Age       1.303840
# Score     7.905694
# Height    5.941380
# dtype: float64
# Name
# Rahul    1
# Priya    1
# Aman     1
# Neha     1
# Rohan    1
# Name: count, dtype: int64
# 0.7276068751089989
# 7.5

# %% [markdown]
# ---
# ## Summary
# - Learned to sort by columns with `sort_values` and by index with `sort_index`.
# - Explored descriptive statistics: mean, median, mode, std, describe.
# - Counted values with `value_counts`.
# - Calculated correlation and covariance.
