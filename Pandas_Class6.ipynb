# %% [markdown]
# # 🐼 Pandas - Class 6: GroupBy & Aggregations
# Welcome to **Class 6** of our Pandas series. Today we’ll learn how to group data and perform aggregations.

# %% [markdown]
# ## 1. Concept of Split–Apply–Combine
# - **Split** the data into groups based on some criteria.
# - **Apply** a function (e.g., sum, mean) to each group.
# - **Combine** the results into a new DataFrame or Series.
#
# This is the core idea behind `groupby`.

# %%
import pandas as pd

# New dataset: Employees, their Department, and Salary
data = {
    "Employee": ["John", "Sarah", "Mike", "Anna", "Tom", "Laura", "Steve", "Kate"],
    "Department": ["HR", "IT", "IT", "Finance", "Finance", "HR", "IT", "Finance"],
    "Salary": [50000, 70000, 72000, 65000, 60000, 52000, 75000, 58000]
}

df = pd.DataFrame(data)
print("Original DataFrame:")
print(df)
# Out:
# Original DataFrame:
#   Employee Department  Salary
# 0     John         HR   50000
# 1    Sarah         IT   70000
# 2     Mike         IT   72000
# 3     Anna    Finance   65000
# 4      Tom    Finance   60000
# 5    Laura         HR   52000
# 6    Steve         IT   75000
# 7     Kate    Finance   58000

# %% [markdown]
# ## 2. Using `groupby()` with Aggregation Functions
# - Use `groupby('col').mean()` or other functions like sum, count, min, max.
# - You can also use `agg()` to pass multiple functions at once.

# %%
print(df.groupby('Department')['Salary'].mean())
print(df.groupby('Department')['Salary'].sum())
print(df.groupby('Department')['Salary'].min())
print(df.groupby('Department')['Salary'].max(), '\n')

print(df.groupby('Department')['Salary'].agg(["mean", "min", "max", "count"]))
# Out:
# Department
# Finance    61000.000000
# HR         51000.000000
# IT         72333.333333
# Name: Salary, dtype: float64
# Department
# Finance    183000
# HR         102000
# IT         217000
# Name: Salary, dtype: int64
# Department
# Finance    58000
# HR         50000
# IT         70000
# Name: Salary, dtype: int64
# Department
# Finance    65000
# HR         52000
# IT         75000
# Name: Salary, dtype: int64
#
#                     mean    min    max  count
# Department
# Finance     61000.000000  58000  65000      3
# HR          51000.000000  50000  52000      2
# IT          72333.333333  70000  75000      3

# %% [markdown]
# ## 3. Multiple Aggregations on Different Columns
# - With `agg()`, you can specify different functions for each column.
# - Example: `df.groupby('Dept').agg({'Salary':'mean', 'Age':'max'})`.

# %%
df = pd.DataFrame({
    "Name": ["Rahul", "Priya", "Aman", "Neha", "Rohan"],
    "Dept": ["IT", "HR", "IT", "HR", "IT"],
    "Age": [20, 22, 21, 23, 20],
    "Salary": [40000, 35000, 45000, 38000, 42000]
})
print(df, '\n')

print(df.groupby("Dept").agg({
    "Salary": "mean",
    "Age": "max"
}), '\n')

print(df.groupby("Dept").agg({
    "Salary": ["mean", "min", "max"],
    "Age": ["min", "max"]
}), '\n')

print(df.groupby("Dept").agg(
    Average_Salary=("Salary", "mean"),
    Maximum_Age=("Age", "max")
))
# Out:
#     Name Dept  Age  Salary
# 0  Rahul   IT   20   40000
# 1  Priya   HR   22   35000
# 2   Aman   IT   21   45000
# 3   Neha   HR   23   38000
# 4  Rohan   IT   20   42000
#
#             Salary  Age
# Dept
# HR    36500.000000   23
# IT    42333.333333   21
#
#             Salary               Age
#               mean    min    max min max
# Dept
# HR    36500.000000  35000  38000  22  23
# IT    42333.333333  40000  45000  20  21
#
#       Average_Salary  Maximum_Age
# Dept
# HR      36500.000000           23
# IT      42333.333333           21

# %% [markdown]
# ## 4. Pivot Tables & Crosstab
# - `pivot_table()` summarizes data like Excel pivot tables.
# - `crosstab()` shows frequency counts of combinations of factors.
# - Both are powerful for summarizing and comparing groups.

# %%
data = {
    "Employee": ["John", "Sarah", "Mike", "Anna", "Tom", "Laura", "Steve", "Kate"],
    "Department": ["HR", "IT", "IT", "Finance", "Finance", "HR", "IT", "Finance"],
    "Salary": [50000, 70000, 72000, 65000, 60000, 52000, 75000, 58000],
    "Age" : [22, 24, 26, 25, 24, 27, 30, 23]
}

df = pd.DataFrame(data)

df["AgeGroup"] = pd.cut(df["Age"], bins=[25, 30, 35, 40], labels=["25-30", "31-35", "36-40"])
crosstab_result = pd.crosstab(df["Department"], df["AgeGroup"])
print(df, '\n')
print(crosstab_result)
# Out:
#   Employee Department  Salary  Age AgeGroup
# 0     John         HR   50000   22      NaN
# 1    Sarah         IT   70000   24      NaN
# 2     Mike         IT   72000   26    25-30
# 3     Anna    Finance   65000   25      NaN
# 4      Tom    Finance   60000   24      NaN
# 5    Laura         HR   52000   27    25-30
# 6    Steve         IT   75000   30    25-30
# 7     Kate    Finance   58000   23      NaN
#
# AgeGroup    25-30
# Department
# HR              1
# IT              2

# %% [markdown]
# ## Mini Practice
# 1. Create a DataFrame with columns: Department, Employee, Salary, Age, City.
# 2. Group by Department to get average Salary and max Age.
# 3. Apply multiple aggregations using agg().
# 4. Create a pivot_table to see mean Salary by Department and City.
# 5. Build a crosstab for Department vs City.

# %%
import pandas as pd
# 1. import pandas as pd
df = pd.DataFrame({
    "Department": ["IT", "HR", "IT", "Finance", "HR", "Finance"],
    "Employee": ["Rahul", "Priya", "Aman", "Neha", "Rohan", "Sneha"],
    "Salary": [50000, 45000, 60000, 55000, 48000, 65000],
    "Age": [25, 28, 30, 27, 24, 32],
    "City": ["Bhopal", "Indore", "Bhopal", "Delhi", "Indore", "Delhi"]
})

print(df)
# 2. Group by Department to get average Salary and max Age
# Write your code here
print(df.groupby('Department').agg({ 'Salary' : 'mean',
                                      'Age' : 'max'}), '\n')

# 3. Apply multiple aggregations using agg()
# Example: mean Salary, max Age per Department
# Write your code here
print(df.groupby('Department').agg({ 'Salary' : ['mean', 'max']}), '\n')

# 4. Create a pivot_table to see mean Salary by Department and City
# Write your code here
pivot = pd.pivot_table(
    df,
    values="Salary",
    index="Department",
    columns="City",
    aggfunc="mean"
)

print(pivot)

# 5. Build a crosstab for Department vs City
# Write your code here
cross_tab = pd.crosstab(df["Department"], df["City"])
print(cross_tab)
# Out:
#   Department Employee  Salary  Age    City
# 0         IT    Rahul   50000   25  Bhopal
# 1         HR    Priya   45000   28  Indore
# 2         IT     Aman   60000   30  Bhopal
# 3    Finance     Neha   55000   27   Delhi
# 4         HR    Rohan   48000   24  Indore
# 5    Finance    Sneha   65000   32   Delhi
#              Salary  Age
# Department
# Finance     60000.0   32
# HR          46500.0   28
# IT          55000.0   30
#
#              Salary
#                mean    max
# Department
# Finance     60000.0  65000
# HR          46500.0  48000
# IT          55000.0  60000
#
# City         Bhopal    Delhi   Indore
# Department
# Finance         NaN  60000.0      NaN
# HR              NaN      NaN  46500.0
# IT          55000.0      NaN      NaN
# City        Bhopal  Delhi  Indore
# Department
# Finance          0      2       0
# HR               0      0       2
# IT               2      0       0

# %% [markdown]
# ---
# ## Summary
# - Learned the split–apply–combine concept.
# - Used `groupby()` with aggregation functions.
# - Applied multiple aggregations to different columns.
# - Explored `pivot_table` and `crosstab` for summarizing data.
